# %% [markdown]
# # Kaggle Competition | Titanic Machine Learning from Disaster

# %% [markdown]
# From the competition homepage: http://www.kaggle.com/c/titanic-gettingStarted

# %% [markdown]
# With help from the iPython Cookbook

# %%
import numpy as np
import pandas as pd
import sklearn
import sklearn.linear_model as lm
import sklearn.cross_validation as cv
import sklearn.grid_search as gs
import sklearn.datasets as ds
import sklearn.neighbors as nb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_csv("data/train.csv") 
test = pd.read_csv("data/test.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# I'm going to convert the `sex` field to binary.
#
# `ticket` and `cabin` have a lot of missing values, so let's get rid of them.

# %%
data = train[['Sex', 'Age', 'Pclass', 'Survived']].copy()
data['Sex'] = data['Sex'] == 'female'
data = data.dropna()

# %% [markdown]
# Now converting data (which is a DataFrame) to a NumPy array so that it can be used by SciKit

# %%
data_np = data.astype(np.int32).values
x = data_np[:,:-1]
y = data_np[:,-1]

# %%
#Notice how I converted it to int32 values

# %% [markdown]
# Looking at the mortality rate of male and females as related to their age

# %%
# Defining boolean vectors
female = x[:,0] == 1
survived = y == 1
# This vector contains the age 
age = x[:,1]

# %%
# Histogram time
bins_ = np.arange(0, 81, 5)
S = {'male': np.histogram(age[survived & ~female], bins=bins_)[0], 
     'female': np.histogram(age[survived & female], bins=bins_)[0]}

# %%
D = {'male': np.histogram(age[~survived & female], bins=bins_)[0], 
     'female': np.histogram(age[~survived & female], bins=bins_)[0]}

# %%
# We now plot the data.
bins = bins_[:-1]
plt.figure(figsize=(14,3));
for i, sex, color in zip((0, 1),
                         ('male', 'female'),
                         ('#3345d0', '#a21dd0')):
    plt.subplot(121 + i);
    plt.bar(bins, S[sex], bottom=D[sex], color=color,
            width=5, label='survived');
    plt.bar(bins, D[sex], color='k', width=5, label='died');
    plt.xlim(0, 80);
    plt.grid(None);
    plt.title(sex + " survival");
    plt.xlabel("Age (years)");
    plt.legend();

# %% [markdown]
# ## Supervised Machine Learning

# %% [markdown]
# Let's try to train a LogisticRegression classifier in order to predict the survival of people based on their gender, age, and class. We first need to create a train and
# a test dataset:

# %%
# We split x and y into train and test datasets.
(x_train, x_test, y_train, y_test) = cv.train_test_split(x, y, test_size=.05)

# %%
# We instantiate the classifier.
logreg = lm.LogisticRegression();

# %%
#Train the model and get the predicted values on the test set.
logreg.fit(x_train, y_train)
y_predicted = logreg.predict(x_test)

# %% [markdown]
# The following figure shows the actual and predicted results.

# %%
plt.figure(figsize=(14, 3));
plt.imshow(np.vstack((y_test, y_predicted)), interpolation='none', cmap='bone');
plt.xticks([]); plt.yticks([]);
plt.title(("Actual and predicted survival outcomes on the test set"));

# %% [markdown]
# The first line shows the survival of several people from the test set (white for survival, black otherwise). The second line shows the values predicted by the model.

# %% [markdown]
# To get an estimation of the performance of the model, we can use the cross_val_score that computes the cross-validation score. This function uses by default a 3-fold stratified cross-validation procedure, but this can be changed with the cv keyword argument.

# %%
cv.cross_val_score(logreg, x, y)
# Out:
# array([ 0.78661088,  0.78991597,  0.78059072])

# %% [markdown]
# The LogisticRegression class accepts a C hyperparameter as argument. This parameter quantifies the regularization strength. To find a good value, we can perform a grid search with the GridSearchCV class. It takes as input an estimator, and a dictionary of parameter values. This new estimator uses cross-validation to select the best parameter.

# %%
grid = gs.GridSearchCV(logreg, {'C': np.logspace(-5, 5, 200)}, n_jobs=4)
grid.fit(x_train, y_train);
grid.best_params_
# Out:
# {'C': 96.588322411587086}

# %%
cv.cross_val_score(grid.best_estimator_, x, y)
# Out:
# array([ 0.78242678,  0.79831933,  0.78481013])

# %%
results = cv.cross_val_score(grid.best_estimator_, x, y)

# %% [markdown]
# Logistic regression is not a regression model, it is a classification model. Yet, it is closely related to linear regression. This model predicts the probability that a binary variable is 1, by applying a sigmoid function (more precisely, a logistic function) to a linear combination of the variables.

# %%
cv.cross_val_score(grid.best_estimator_, x, y)
# Out:
# array([ 0.78242678,  0.79831933,  0.78481013])

# %% [markdown]
# ## K-Nearest Neighbor classifier

# %%
knc = nb.KNeighborsClassifier()

# %%
(x_train, x_test, y_train, y_test) = cv.train_test_split(x, y, test_size=.25)

# %%
knc.fit(x_train, y_train);

# %%
knc.score(x_test, y_test)
# Out:
# 0.78770949720670391

# %% [markdown]
# The idea of K-nearest neighbors is as follows: given a new point in the feature space, find the
# K closest points from the training set and assign the label of the majority of those points.
# The distance is generally the Euclidean distance, but other distances can be used too.
#
# The number K is a hyperparameter of the model. If it is too small, the model will not generalize well (high variance). In particular, it will be highly sensitive to outliers. By contrast, the precision of the model will worsen if K is too large. At the extreme, if K is equal to the total number of points, the model will always predict the exact same value disregarding the input (high bias). There are heuristics to choose this hyperparameter (see the next section).
#
#
# It should be noted that no model is learned by a K-nearest neighbor algorithm; the classifier
# just stores all data points and compares any new target points with them. This is an example of instance-based learning. It is in contrast to other classifiers such as the logistic regression model, which explicitly learns a simple mathematical model on the training data.
#
#
# The K-nearest neighbors method works well on complex classification problems that have
# irregular decision boundaries. However, it might be computationally intensive with large training datasets because a large number of distances have to be computed for testing. Dedicated tree-based data structures such as K-D trees or ball trees can be used to accelerate the search of nearest neighbors.
#
#
# The K-nearest neighbors method can be used for classification, like here, and also for
# regression problems. The model assigns the average of the target value of the nearest neighbors. In both cases, different weighting strategies can be used.
